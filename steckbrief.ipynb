# %%
####
# Legt einen Ordner an, öffnet ihn in VS Code und schreibt ein winziges Programm:
# Speichert euren Namen, euren Wohnort und euer Hobby jeweils in einer eigenen
# Variablen. Danach gibt das Programm drei schöne Sätze aus, in denen diese Werte
# vorkommen.
# Git: Repository starten → Änderung vormerken → Commit mit einer sinnvollen
# Nachricht → veröffentlichen → im Browser anschauen.
####

name = "Thorsten Schwarck"
wohnort = "Berlin"
hobby = "Sport, Filmen, Hiken"

print(f"Hallo, mein Name ist {name}.")
print(f"Ich wohne in {wohnort}.")
print(f"In meiner Freizeit beschäftige ich mich gerne mit {hobby}.")
# Out:
# Hallo, mein Name ist Thorsten Schwarck.
# Ich wohne in Berlin.
# In meiner Freizeit beschäftige ich mich gerne mit Sport, Filmen, Hiken.
